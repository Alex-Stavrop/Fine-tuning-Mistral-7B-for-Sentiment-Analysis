# %% [markdown]
# ## 🧠 Fine-Tuning Mistral 7B for Sentiment Analysis
# ![Financial Dataset Overview](https://miro.medium.com/v2/resize:fit:2000/format:webp/1*GMYQoIl2pFDc5i8H0CB5-w.jpeg)
#
# ### Project Objective
# The focus here is on sentiment analysis in financial and economic information. Understanding market trends, investor confidence, and consumer behavior is critical for businesses. Also, identifying potential risks and making smart investment decisions are key applications of this analysis.
#
# ### Preparing Mistral 7B
# Before starting the fine-tuning process of Mistral model, selecting the right dataset is crucial. Annotated datasets in finance and economics are hard to come by, as most are kept private.
#
# ### The FinancialPhraseBank Dataset
# I found the FinancialPhraseBank dataset, created by Aalto University School of Business. It contains around 5000 sentences, each annotated for sentiment analysis from an investor’s perspective. This means every sentence is labeled as either having a positive, negative, or neutral impact on stock prices.
#
# ### Dataset’s Importance
# This dataset is crucial for understanding how financial news is perceived by retail investors. It classifies sentiments in a structured way, making it easier to analyze the complex dynamics of market sentiment. It's been a valuable tool in research since it was first used in the 2014 study by Malo et al.
#
# ### Next Steps
# With this dataset, I'll start fine-tuning the Mistral model. The goal is to make this model proficient in detecting and understanding sentiments in financial texts. This could lead to more accurate insights into how different news impacts investor behavior and market trends.

# %% [markdown]
# As a first step, we install the specific libraries necessary to make this example work.

# %% [markdown]
# ## 🛠️ Library Installation for Language Model Fine-Tuning
#
# As a first step in our language model fine-tuning journey, let's get familiar with the specific libraries we'll be using:
#
# - 🚀 **accelerate**: A distributed training library for PyTorch by HuggingFace. It allows training on multiple GPUs or CPUs in parallel, speeding up training in multi-GPU environments. We won't be using it in this example, but it's good to know about.
#
# - 🧠 **peft**: A Python library by HuggingFace for efficient adaptation of pre-trained language models (PLMs). PEFT methods fine-tune a small number of model parameters, reducing computational and storage costs.
#
# - 🌟 **bitsandbytes**: Developed by Tim Dettmers, this lightweight wrapper around CUDA custom functions includes 8-bit optimizers, matrix multiplication, and quantization functions. It supports models in 4-bit precision while computations still occur in 16 or 32-bit.
#
# - 📚 **transformers**: A comprehensive Python library for natural language processing (NLP) by HuggingFace. It offers a range of pre-trained models for various NLP tasks like text classification, question answering, and machine translation.
#
# - 🤖 **trl**: Another tool from HuggingFace, trl is a full-stack library for training transformer language models with Reinforcement Learning. It covers everything from Supervised Fine-tuning (SFT) and Reward Modeling (RM) to Proximal Policy Optimization (PPO).

# %%
pip install -q -U accelerate peft bitsandbytes transformers trl
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 🖥️ Setting Environment Variables for PyTorch and Transformers
#
# The code segment performs the following actions by importing the `os` module and setting two crucial environment variables:
#
# - 🌐 **CUDA_VISIBLE_DEVICES**:
#   - This environment variable instructs PyTorch on which GPUs to use.
#   - By setting it to `0`, we specify that PyTorch should use the first GPU.
#
# - 🔀 **TOKENIZERS_PARALLELISM**:
#   - This variable indicates to the Hugging Face Transformers library how to handle the tokenization process.
#   - Setting it to `false` means the tokenization process will not be parallelized.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %% [markdown]
# The code import warnings; warnings.filterwarnings("ignore") imports the warnings module and sets the warning filter to ignore. This means that all warnings will be suppressed and will not be displayed. Actually during training there are many warnings that do not prevent the fine-tuning but can be distracting and make you wonder if you are doing the correct things.

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# In the following cell there are all the other imports for running the notebook

# %%
import numpy as np
import pandas as pd
import os
from tqdm import tqdm
import bitsandbytes as bnb
import torch
import torch.nn as nn
import transformers
from datasets import Dataset
from peft import LoraConfig, PeftConfig
from trl import SFTTrainer
from transformers import (AutoModelForCausalLM, 
                          AutoTokenizer, 
                          BitsAndBytesConfig, 
                          TrainingArguments, 
                          pipeline, 
                          logging)
from sklearn.metrics import (accuracy_score, 
                             classification_report, 
                             confusion_matrix)
from sklearn.model_selection import train_test_split
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/trl/trainer/ppo_config.py:141: UserWarning: The `optimize_cuda_cache` arguement will be deprecated soon, please use `optimize_device_cache` instead.
#   warnings.warn(

# %% [markdown]
# ## 📊 Data Preparation Steps for Fine-Tuning
#
# The following steps are executed in the next code cell to prepare our datasets for fine-tuning the Mistral 7B model:
#
# 1. **Data Reading**:
#    - Reads the input dataset from the `all-data.csv` file.
#    - This CSV file contains two columns: `sentiment` and `text`.
#
# 2. **Dataset Splitting**:
#    - Splits the dataset into training and test sets, each containing 300 samples.
#    - The split is stratified by sentiment to include positive, neutral, and negative sentiments in each set.
#
# 3. **Data Shuffling**:
#    - Shuffles the training data in a replicable order using `random_state=10`.
#
# 4. **Prompt Transformation**:
#    B- Transforms the texts in the train and test data into prompts for Mistral .
#    - The train prompts include the expected answers for fine-tuning.
#
# 5. **Evaluation Data Preparation**:
#    - Handles the residual data not included in train or test sets as evaluation data.
#    - Samples this data with repetition to balance the sentiment distribution, particularly increasing the number of negative instances.
#
# 6. **Data Wrapping**:
#    - Wraps the train and evaluation data using a class from Hugging Face ([Hugging Face Documentation](https://huggingface.co/docs/datasets/index)).
#
# This process results in the creation of `train_data`, `eval_data`, and `test_data` datasets, ready for use in our fine-tuning pipeline.

# %%
filename = "../input/sentiment-analysis-for-financial-news/all-data.csv"

df = pd.read_csv(filename, 
                 names=["sentiment", "text"],
                 encoding="utf-8", encoding_errors="replace")

X_train = list()
X_test = list()
for sentiment in ["positive", "neutral", "negative"]:
    train, test  = train_test_split(df[df.sentiment==sentiment], 
                                    train_size=300,
                                    test_size=300, 
                                    random_state=42)
    X_train.append(train)
    X_test.append(test)

X_train = pd.concat(X_train).sample(frac=1, random_state=10)
X_test = pd.concat(X_test)

eval_idx = [idx for idx in df.index if idx not in list(train.index) + list(test.index)]
X_eval = df[df.index.isin(eval_idx)]
X_eval = (X_eval
          .groupby('sentiment', group_keys=False)
          .apply(lambda x: x.sample(n=50, random_state=10, replace=True)))
X_train = X_train.reset_index(drop=True)

def generate_prompt(data_point):
    return f"""
            Analyze the sentiment of the news headline enclosed in square brackets, 
            determine if it is positive, neutral, or negative, and return the answer as 
            the corresponding sentiment label "positive" or "neutral" or "negative".

            [{data_point["text"]}] = {data_point["sentiment"]}
            """.strip()

def generate_test_prompt(data_point):
    return f"""
            Analyze the sentiment of the news headline enclosed in square brackets, 
            determine if it is positive, neutral, or negative, and return the answer as 
            the corresponding sentiment label "positive" or "neutral" or "negative".

            [{data_point["text"]}] = """.strip()

X_train = pd.DataFrame(X_train.apply(generate_prompt, axis=1), 
                       columns=["text"])
X_eval = pd.DataFrame(X_eval.apply(generate_prompt, axis=1), 
                      columns=["text"])

y_true = X_test.sentiment
X_test = pd.DataFrame(X_test.apply(generate_test_prompt, axis=1), columns=["text"])

train_data = Dataset.from_pandas(X_train)
eval_data = Dataset.from_pandas(X_eval)

# %% [markdown]
# ## 📈 Evaluation Function for Sentiment Model
#
# The next step involves creating a function to evaluate the performance of our fine-tuned sentiment analysis model. The function carries out the following steps:
#
# 1. **Label Mapping**:
#    - Maps sentiment labels to numerical representations:
#      - `2` for positive
#      - `1` for neutral
#      - `0` for negative
#
# 2. **Accuracy Calculation**:
#    - Computes the model's accuracy on the test dataset.
#
# 3. **Accuracy Report Generation**:
#    - Produces an accuracy report detailing performance for each sentiment label.
#
# 4. **Classification Report**:
#    - Generates a classification report of the model, providing metrics like precision, recall, and F1-score.
#
# 5. **Confusion Matrix Creation**:
#    - Constructs a confusion matrix to visually represent the model's performance in predicting each sentiment category.

# %%
def evaluate(y_true, y_pred):
    labels = ['positive', 'neutral', 'negative']
    mapping = {'positive': 2, 'neutral': 1, 'none':1, 'negative': 0}
    def map_func(x):
        return mapping.get(x, 1)
    
    y_true = np.vectorize(map_func)(y_true)
    y_pred = np.vectorize(map_func)(y_pred)
    
    # Calculate accuracy
    accuracy = accuracy_score(y_true=y_true, y_pred=y_pred)
    print(f'Accuracy: {accuracy:.3f}')
    
    # Generate accuracy report
    unique_labels = set(y_true)  # Get unique labels
    
    for label in unique_labels:
        label_indices = [i for i in range(len(y_true)) 
                         if y_true[i] == label]
        label_y_true = [y_true[i] for i in label_indices]
        label_y_pred = [y_pred[i] for i in label_indices]
        accuracy = accuracy_score(label_y_true, label_y_pred)
        print(f'Accuracy for label {label}: {accuracy:.3f}')
        
    # Generate classification report
    class_report = classification_report(y_true=y_true, y_pred=y_pred)
    print('\nClassification Report:')
    print(class_report)
    
    # Generate confusion matrix
    conf_matrix = confusion_matrix(y_true=y_true, y_pred=y_pred, labels=[0, 1, 2])
    print('\nConfusion Matrix:')
    print(conf_matrix)

# %% [markdown]
# ## 🤖 Model Loading and Quantization for  Mistral 7B
#
# The process for loading and quantizing the Mistral 7B model involves several steps:
#
# ### Model Loading and Quantization:
#
# - **Load Mistral 7B Model**:
#   - The code begins by loading the Mistral 7B language model from the Hugging Face Hub.
#
# - **Data Type Configuration**:
#   - Acquires the `float16` data type from the torch library for computational purposes.
#
# - **BitsAndBytesConfig Settings**:
#   - Creates a `BitsAndBytesConfig` object with specific settings:
#     1. `load_in_4bit`: Loads model weights in 4-bit format.
#     2. `bnb_4bit_quant_type`: Sets quantization type to "nf4" (4-bit NormalFloat).
#     3. `bnb_4bit_compute_dtype`: Utilizes `float16` for computations.
#     4. `bnb_4bit_use_double_quant`: Disables double quantization to manage memory footprint.
#
# - **Model Configuration**:
#   - Generates an `AutoModelForCausalLM` object from the Mistral 7B model, applying the quantization settings from `BitsAndBytesConfig`.
#
# - **Caching and Token Probability**:
#   - Disables caching for the model.
#   - Sets the pre-training token probability to 1.
#
# ### Tokenizer Loading:
#
# - **Tokenizer Configuration**:
#   - Loads the tokenizer for theMistral 7B language model.
#   - Sets the padding token as the end-of-sequence (EOS) token.
#   - Configures padding to be on the "right" side, ensuring proper padding direction for Mistral 7B.

# %%
model_name = "/kaggle/input/mistral/pytorch/7b-v0.1-hf/1"

compute_dtype = getattr(torch, "float16")

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    quantization_config=bnb_config, 
)

model.config.use_cache = False
model.config.pretraining_tp = 1

tokenizer = AutoTokenizer.from_pretrained(model_name, 
                                          trust_remote_code=True,
                                         )
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ## 📰 Sentiment Prediction Function Using Mistral 7B
#
# In the next cell, we define a function to predict the sentiment of news headlines using the Mistral 7B language model. This function is designed with the following parameters and process:
#
# ### Function Parameters:
#
# - **`test`**:
#   - A Pandas DataFrame containing the news headlines for sentiment prediction.
#
# - **`model`**:
#   - The pre-trained Mistral 7B language model.
#
# - **`tokenizer`**:
#   - The tokenizer corresponding to the Mistral 7B model.
#
# ### Prediction Process:
#
# - **For each news headline**:
#   1. **Create a Prompt**:
#      - Formulates a prompt asking the Mistral 7B model to analyze the sentiment of the headline and return a sentiment label.
#
#   2. **Generate Text**:
#      - Utilizes the `pipeline()` function from the Hugging Face Transformers library to generate text from the Mistral 7B model, based on the prompt.
#
#   3. **Extract Sentiment Label**:
#      - Derives the predicted sentiment label from the generated text.
#
#   4. **Append to y_pred**:
#      - Adds the predicted sentiment label to the `y_pred` list.
#
# - **Return**:
#   - Outputs the `y_pred` list containing all predicted sentiment labels.
#
# ### `pipeline()` Function Usage:
#
# - This function generates text from the Mistral 7B model.
# - **Parameters**:
#   - `task`: Specifies text generation as the task.
#   - `model`: Indicates the pre-trained Mistral 7B language model.
#   - `tokenizer`: Specifies the tokenizer for the Mistral 7B model.
#   - `max_new_tokens`: Sets the maximum number of new tokens to generate.
#   - `temperature`: Controls the randomness of the generated text. Lower temperature means less randomness (more predictable), while a higher temperature leads to more creative outputs.
#
# ### Sentiment Label Determination:
#
# - The function uses an if statement to determine the sentiment label:
#   - If the generated text contains "positive", the label is "positive".
#   - If the generated text contains "negative", the label is "negative".
#   - If the generated text contains "neutral", the label is "neutral".
#
# This function effectively automates the sentiment analysis of news

# %%
def predict(test, model, tokenizer):
    y_pred = []
    for i in tqdm(range(len(X_test))):
        prompt = X_test.iloc[i]["text"]
        pipe = pipeline(task="text-generation", 
                        model=model, 
                        tokenizer=tokenizer, 
                        max_new_tokens = 1, 
                        temperature = 0.0,
                       )
        result = pipe(prompt)
        answer = result[0]['generated_text'].split("=")[-1]
        if "positive" in answer:
            y_pred.append("positive")
        elif "negative" in answer:
            y_pred.append("negative")
        elif "neutral" in answer:
            y_pred.append("neutral")
        else:
            y_pred.append("none")
    return y_pred

# %% [markdown]
# ## 🧪 Testing Mistral 7B Model Pre-Fine-Tuning
#
# At this stage of our project, we are set to test the capabilities of Mistral 7b-v0.1-hf model on our dataset. This test will be conducted without any fine-tuning to understand the baseline performance. Here's what this step involves:
#
# ### Objective:
#
# - **Baseline Evaluation**:
#   - The primary goal is to assess how well the Mistral model performs on our sentiment analysis problem in it's pre-trained state.
#
# ### Importance:
#
# - **Insight Gathering**:
#   - Testing the model without fine-tuning provides valuable insights into its inherent capability and limitations.
#
# - **Baseline Establishment**:
#   - This step helps in establishing a baseline performance of the model. It acts as a reference point to measure the impact of subsequent fine-tuning.
#
  2.56it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  95%|█████████▌| 855/900 [05:39<00:17,  2.64it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  95%|█████████▌| 856/900 [05:39<00:17,  2.53it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  95%|█████████▌| 857/900 [05:40<00:17,  2.47it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  95%|█████████▌| 858/900 [05:40<00:17,  2.41it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  95%|█████████▌| 859/900 [05:41<00:17,  2.38it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  96%|█████████▌| 860/900 [05:41<00:16,  2.36it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  96%|█████████▌| 861/900 [05:41<00:15,  2.48it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  96%|█████████▌| 862/900 [05:42<00:15,  2.43it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  96%|█████████▌| 863/900 [05:42<00:14,  2.54it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  96%|█████████▌| 864/900 [05:42<00:13,  2.62it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  96%|█████████▌| 865/900 [05:43<00:13,  2.68it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  96%|█████████▌| 866/900 [05:43<00:12,  2.73it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  96%|█████████▋| 867/900 [05:44<00:13,  2.47it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  96%|█████████▋| 868/900 [05:44<00:12,  2.57it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  97%|█████████▋| 869/900 [05:44<00:12,  2.49it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  97%|█████████▋| 870/900 [05:45<00:12,  2.43it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  97%|█████████▋| 871/900 [05:45<00:11,  2.54it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  97%|█████████▋| 872/900 [05:46<00:11,  2.47it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  97%|█████████▋| 873/900 [05:46<00:11,  2.42it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  97%|█████████▋| 874/900 [05:47<00:10,  2.39it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  97%|█████████▋| 875/900 [05:47<00:10,  2.37it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  97%|█████████▋| 876/900 [05:47<00:10,  2.35it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  97%|█████████▋| 877/900 [05:48<00:09,  2.34it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  98%|█████████▊| 878/900 [05:48<00:09,  2.33it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  98%|█████████▊| 879/900 [05:49<00:09,  2.33it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  98%|█████████▊| 880/900 [05:49<00:08,  2.46it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  98%|█████████▊| 881/900 [05:49<00:07,  2.41it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  98%|█████████▊| 882/900 [05:50<00:07,  2.38it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  98%|█████████▊| 883/900 [05:50<00:07,  2.35it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  98%|█████████▊| 884/900 [05:51<00:07,  2.24it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  98%|█████████▊| 885/900 [05:51<00:06,  2.39it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  98%|█████████▊| 886/900 [05:52<00:05,  2.36it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  99%|█████████▊| 887/900 [05:52<00:05,  2.35it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  99%|█████████▊| 888/900 [05:52<00:04,  2.47it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  99%|█████████▉| 889/900 [05:53<00:04,  2.31it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  99%|█████████▉| 890/900 [05:53<00:04,  2.31it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  99%|█████████▉| 891/900 [05:54<00:03,  2.45it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  99%|█████████▉| 892/900 [05:54<00:03,  2.55it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  99%|█████████▉| 893/900 [05:54<00:02,  2.48it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  99%|█████████▉| 894/900 [05:55<00:02,  2.57it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  99%|█████████▉| 895/900 [05:55<00:02,  2.49it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# 100%|█████████▉| 896/900 [05:56<00:01,  2.58it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# 100%|█████████▉| 897/900 [05:56<00:01,  2.65it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# 100%|█████████▉| 898/900 [05:56<00:00,  2.42it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# 100%|█████████▉| 899/900 [05:57<00:00,  2.39it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# 100%|██████████| 900/900 [05:57<00:00,  2.52it/s]

# %% [markdown]
# In the following cell, we evaluate the results. There is little to be said, it is performing really terribly because the 7b-hf model tends to just predict a neutral sentiment and seldom it detects positive or negative sentiment.

# %%
evaluate(y_true, y_pred)
# Out:
# Accuracy: 0.544
# Accuracy for label 0: 0.487
# Accuracy for label 1: 0.210
# Accuracy for label 2: 0.937
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.49      0.65       300
#            1       0.38      0.21      0.27       300
#            2       0.48      0.94      0.64       300
#
#     accuracy                           0.54       900
#    macro avg       0.61      0.54      0.52       900
# weighted avg       0.61      0.54      0.52       900
#
#
# Confusion Matrix:
# [[146  82  72]
#  [  5  63 232]
#  [  0  19 281]]

# %% [markdown]
# ## 🔧 Setting Up for Fine-Tuning with SFTTrainer and PEFT
#
# We're now ready to set up the environment for fine-tuning our large language models. This setup involves configuring and initializing the Simple Fine-tuning Trainer (SFTTrainer) using the Parameter-Efficient Fine-Tuning (PEFT) method. Here's a breakdown of the key components:
#
# ### PEFT Configuration:
#
# - **`peft_config` Object**:
#   - Specifies PEFT parameters, focusing on refining a limited set of model parameters. Key parameters include:
#     - `lora_alpha`: Learning rate for LoRA update matrices.
#     - `lora_dropout`: Dropout probability for LoRA matrices.
#     - `r`: Rank of the LoRA update matrices.
#     - `bias`: Type of bias (none, additive, learned).
#     - `task_type`: Task type for training (CAUSAL_LM, MASKED_LM).
#
# ### Training Arguments:
#
# - **`training_arguments` Object**:
#   - Sets parameters for model training, including:
#     - `output_dir`: Directory for logs and checkpoints.
#     - `num_train_epochs`: Number of training epochs.
#     - `per_device_train_batch_size`: Batch size per device.
#     - `gradient_accumulation_steps`: Batches for gradient accumulation.
#     - `optim`: Chosen optimizer.
#     - `save_steps`, `logging_steps`: Checkpoint and logging intervals.
#     - `learning_rate`, `weight_decay`: Optimizer settings.
#     - `fp16`, `bf16`: Precision settings.
#     - `max_grad_norm`, `max_steps`: Gradient and step limits.
#     - `warmup_ratio`: Learning rate warmup proportion.
#     - `group_by_length`: Sample grouping strategy.
#     - `lr_scheduler_type`: Learning rate scheduler type.
#     - `report_to`: Metrics reporting tools.
#     - `evaluation_strategy`: Model evaluation strategy during training.
#
# ### SFTTrainer Initialization:
#
# - **Setting Up the SFTTrainer**:
#   - A custom trainer class from the PEFT library.
#   - Initialized with:
#     - `model`: Model to be trained.
#     - `train_dataset`, `eval_dataset`: Training and evaluation datasets.
#     - `peft_config`: PEFT configuration.
#     - `dataset_text_field`: Text field name in the dataset.
#     - `tokenizer`: Tokenizer for the model.
#     - `args`: Training arguments.
#     - `packing`: Packing strategy for training samples.
#     - `max_seq_length`: Maximum sequence length.
#
# ### Training the Model:
#
# - **Using the SFTTrainer**:
#   - After initialization, the SFTTrainer is ready to train the model using the `train()` method.
#
# This setup aims to efficiently fine-tune our large language models, utilizing PEFT to save computational resources and address issues like catastrophic forgetting. The SFTTrainer provides a tailored approach to fine-tune the model parameters effectively.

# %%
peft_config = LoraConfig(
    lora_alpha=16,
    lora_dropout=0.1,
    r=64,
    bias="none",
    task_type="CAUSAL_LM",
)

training_arguments = TrainingArguments(
    output_dir="logs",
    num_train_epochs=3,
    per_device_train_batch_size=1,
    gradient_accumulation_steps=8, # 4
    optim="paged_adamw_32bit",
    save_steps=0,
    logging_steps=25,
    learning_rate=2e-4,
    weight_decay=0.001,
    fp16=True,
    bf16=False,
    max_grad_norm=0.3,
    max_steps=-1,
    warmup_ratio=0.03,
    group_by_length=True,
    lr_scheduler_type="cosine",
    report_to="tensorboard",
    evaluation_strategy="epoch"
)

trainer = SFTTrainer(
    model=model,
    train_dataset=train_data,
    eval_dataset=eval_data,
    peft_config=peft_config,
    dataset_text_field="text",
    tokenizer=tokenizer,
    args=training_arguments,
    packing=False,
    max_seq_length=1024,
)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %% [markdown]
# ## 🚀 Model Training and Saving with Trainer
#
# The next code cell is dedicated to training our model and then saving the fine-tuned version. This is how it will be executed:
#
# ### Training the Model:
#
# - **Training Execution**:
#   - The model training is carried out by invoking the `trainer.train()` method from our previously configured trainer.
#
# ### Saving the Trained Model:
#
# - **Model Storage**:
#   - Post training, the model is saved to the `trained-model` directory. This ensures that our fine-tuned model is securely stored and accessible for future use.
#
# ### Performance Expectation:
#
# - **Training Speed**:
#   - Utilizing the standard GPU P100 provided by Kaggle, we anticipate the training process to be relatively fast, leveraging the high computational power of the GPU.

# %%
# Train model
trainer.train()

# Save trained model
trainer.model.save_pretrained("trained-model")
# Out:
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='336' max='336' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [336/336 38:58, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.839500</td>
#       <td>0.750339</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.623400</td>
#       <td>0.678037</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# Afterwards, loading the TensorBoard extension and start TensorBoard, pointing to the logs/runs directory, which is assumed to contain the training logs and checkpoints for your model, will allow you to understand how the models fits during the training.

# %%
# %reload_ext tensorboard
# %tensorboard --logdir logs/runs
# Out:
# Reusing TensorBoard on port 6006 (pid 140), started 0:00:43 ago. (Use '!kill 140' to kill it.)
#       <iframe id="tensorboard-frame-23b8c1e9392456de" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-23b8c1e9392456de");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## 📈 Model Prediction and Evaluation
#
# Next, we'll proceed with the final stage of our model's performance assessment. This involves two key steps: predicting sentiment labels for the test set and evaluating the model's overall performance. Here's the breakdown:
#
# ### Predicting Sentiment Labels:
#
# - **Using `predict()` Function**:
#   - The code will first utilize the `predict()` function to determine sentiment labels for the test dataset.
#   - This step is crucial in seeing how well our model generalizes to unseen data.
#
# ### Evaluating Model Performance:
#
# - **Applying `evaluate()` Function**:
#   - Following predictions, the `evaluate()` function will be called to assess the model's performance on the test set.
#   - This evaluation focuses on metrics such as accuracy, precision, and recall for individual sentiment labels.
#
# ### Expected Results:
#
# - **High Overall Accuracy**:
#   - We anticipate an impressive overall accuracy exceeding 0.8.
#   - This indicates a strong performance of the model in correctly classifying sentiments.
#
# - **Sentiment Label Accuracy**:
#   - High accuracy is expected for individual sentiment labels.
#   - However, the prediction of the 'neutral' label might still have room for improvement.
#
# - **Reflection on Fine-Tuning Success**:
#   - These results, especially with limited data, showcase the efficacy of our fine-tuning approach.
#   - It's noteworthy how targeted fine-tuning can significantly enhance model performance.
#
# By completing these steps, we gain a comprehensive view of our model's capabilities in sentiment analysis post-fine-tuning.

# %%
y_pred = predict(test, model, tokenizer)
evaluate(y_true, y_pred)
# Out:
#   0%|          | 0/900 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   0%|          | 1/900 [00:00<07:09,  2.09it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   0%|          | 2/900 [00:00<06:57,  2.15it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   0%|          | 3/900 [00:01<06:50,  2.18it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   0%|          | 4/900 [00:01<06:47,  2.20it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 5/900 [00:02<06:19,  2.36it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 6/900 [00:02<06:48,  2.19it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 7/900 [00:03<06:46,  2.20it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 8/900 [00:03<06:44,  2.20it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 9/900 [00:03<06:20,  2.34it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 10/900 [00:04<06:03,  2.45it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 11/900 [00:04<05:52,  2.52it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|▏         | 12/900 [00:05<05:44,  2.58it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|▏         | 13/900 [00:05<05:38,  2.62it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 14/900 [00:05<06:14,  2.36it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 15/900 [00:06<06:22,  2.32it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 16/900 [00:06<06:04,  2.42it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 17/900 [00:07<06:14,  2.36it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 18/900 [00:07<06:20,  2.32it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 19/900 [00:08<06:25,  2.28it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 20/900 [00:08<06:46,  2.16it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 21/900 [00:09<06:43,  2.18it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 22/900 [00:09<06:40,  2.19it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         | 23/900 [00:10<06:38,  2.20it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         | 24/900 [00:10<06:37,  2.20it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         | 25/900 [00:10<06:54,  2.11it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         | 26/900 [00:11<06:47,  2.15it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         | 27/900 [00:11<06:20,  2.29it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         | 28/900 [00:12<06:23,  2.27it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         | 29/900 [00:12<06:04,  2.39it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         | 30/900 [00:13<06:11,  2.34it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         | 31/900 [00:13<05:55,  2.44it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   4%|▎         | 32/900 [00:13<06:05,  2.37it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   4%|▎         | 33/900 [00:14<06:12,  2.33it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   4%|▍         | 34/900 [00:14<05:55,  2.43it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   4%|▍         | 35/900 [00:15<06:04,  2.37it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   4%|▍         | 36/900 [00:15<05:50,  2.47it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   4%|▍         | 37/900 [00:15<06:01,  2.39it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   4%|▍         | 38/900 [00:16<05:47,  2.48it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   4%|▍         | 39/900 [00:16<05:38,  2.55it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   4%|▍         | 40/900 [00:17<05:31,  2.59it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   5%|▍         | 41/900 [00:17<05:48,  2.46it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   5%|▍         | 42/900 [00:17<05:59,  2.39it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   5%|▍         | 43/900 [00:18<05:45,  2.48it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   5%|▍         | 44/900 [00:18<05:35,  2.55it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   5%|▌         | 45/900 [00:19<05:29,  2.60it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   5%|▌         | 46/900 [00:19<06:02,  2.35it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   5%|▌         | 47/900 [00:20<06:08,  2.31it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   5%|▌         | 48/900 [00:20<05:51,  2.42it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   5%|▌         | 49/900 [00:20<05:39,  2.50it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   6%|▌         | 50/900 [00:21<06:09,  2.30it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   6%|▌         | 51/900 [00:21<06:13,  2.27it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   6%|▌         | 52/900 [00:22<05:55,  2.39it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   6%|▌         | 53/900 [00:22<05:41,  2.48it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   6%|▌         | 54/900 [00:22<05:32,  2.55it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   6%|▌         | 55/900 [00:23<05:25,  2.60it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   6%|▌         | 56/900 [00:23<05:20,  2.64it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   6%|▋         | 57/900 [00:23<05:16,  2.66it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   6%|▋         | 58/900 [00:24<05:34,  2.51it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   7%|▋         | 59/900 [00:24<05:47,  2.42it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   7%|▋         | 60/900 [00:25<05:35,  2.50it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   7%|▋         | 61/900 [00:25<05:27,  2.56it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   7%|▋         | 62/900 [00:25<05:21,  2.61it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   7%|▋         | 63/900 [00:26<05:17,  2.64it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   7%|▋         | 64/900 [00:26<05:14,  2.66it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   7%|▋         | 65/900 [00:27<05:12,  2.68it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   7%|▋         | 66/900 [00:27<05:10,  2.69it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   7%|▋         | 67/900 [00:27<05:29,  2.53it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   8%|▊         | 68/900 [00:28<05:42,  2.43it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   8%|▊         | 69/900 [00:28<05:31,  2.51it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   8%|▊         | 70/900 [00:29<05:22,  2.57it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   8%|▊         | 71/900 [00:29<05:37,  2.46it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   8%|▊         | 72/900 [00:29<05:27,  2.52it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   8%|▊         |
  2.52it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  92%|█████████▏| 828/900 [05:39<00:27,  2.58it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  92%|█████████▏| 829/900 [05:39<00:27,  2.61it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  92%|█████████▏| 830/900 [05:39<00:26,  2.64it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  92%|█████████▏| 831/900 [05:40<00:25,  2.67it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  92%|█████████▏| 832/900 [05:40<00:26,  2.52it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  93%|█████████▎| 833/900 [05:41<00:27,  2.43it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  93%|█████████▎| 834/900 [05:41<00:26,  2.51it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  93%|█████████▎| 835/900 [05:41<00:25,  2.57it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  93%|█████████▎| 836/900 [05:42<00:27,  2.33it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  93%|█████████▎| 837/900 [05:42<00:27,  2.30it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  93%|█████████▎| 838/900 [05:43<00:27,  2.28it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  93%|█████████▎| 839/900 [05:43<00:25,  2.39it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  93%|█████████▎| 840/900 [05:44<00:26,  2.23it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  93%|█████████▎| 841/900 [05:44<00:26,  2.23it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  94%|█████████▎| 842/900 [05:45<00:26,  2.23it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  94%|█████████▎| 843/900 [05:45<00:25,  2.23it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  94%|█████████▍| 844/900 [05:45<00:25,  2.23it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  94%|█████████▍| 845/900 [05:46<00:24,  2.23it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  94%|█████████▍| 846/900 [05:46<00:22,  2.36it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  94%|█████████▍| 847/900 [05:47<00:21,  2.46it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  94%|█████████▍| 848/900 [05:47<00:20,  2.53it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  94%|█████████▍| 849/900 [05:47<00:20,  2.43it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  94%|█████████▍| 850/900 [05:48<00:19,  2.52it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  95%|█████████▍| 851/900 [05:48<00:18,  2.58it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  95%|█████████▍| 852/900 [05:49<00:18,  2.62it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  95%|█████████▍| 853/900 [05:49<00:19,  2.37it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  95%|█████████▍| 854/900 [05:49<00:18,  2.46it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  95%|█████████▌| 855/900 [05:50<00:17,  2.54it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  95%|█████████▌| 856/900 [05:50<00:18,  2.44it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  95%|█████████▌| 857/900 [05:51<00:18,  2.38it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  95%|█████████▌| 858/900 [05:51<00:18,  2.33it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  95%|█████████▌| 859/900 [05:52<00:17,  2.30it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  96%|█████████▌| 860/900 [05:52<00:17,  2.27it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  96%|█████████▌| 861/900 [05:52<00:16,  2.39it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  96%|█████████▌| 862/900 [05:53<00:16,  2.34it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  96%|█████████▌| 863/900 [05:53<00:15,  2.45it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  96%|█████████▌| 864/900 [05:54<00:14,  2.52it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  96%|█████████▌| 865/900 [05:54<00:13,  2.58it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  96%|█████████▌| 866/900 [05:54<00:12,  2.62it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  96%|█████████▋| 867/900 [05:55<00:13,  2.37it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  96%|█████████▋| 868/900 [05:55<00:12,  2.47it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  97%|█████████▋| 869/900 [05:56<00:12,  2.39it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  97%|█████████▋| 870/900 [05:56<00:12,  2.34it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  97%|█████████▋| 871/900 [05:57<00:11,  2.44it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  97%|█████████▋| 872/900 [05:57<00:11,  2.37it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  97%|█████████▋| 873/900 [05:57<00:11,  2.33it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  97%|█████████▋| 874/900 [05:58<00:11,  2.30it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  97%|█████████▋| 875/900 [05:58<00:10,  2.28it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  97%|█████████▋| 876/900 [05:59<00:10,  2.26it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  97%|█████████▋| 877/900 [05:59<00:10,  2.25it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  98%|█████████▊| 878/900 [06:00<00:09,  2.24it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  98%|█████████▊| 879/900 [06:00<00:09,  2.24it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  98%|█████████▊| 880/900 [06:00<00:08,  2.37it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  98%|█████████▊| 881/900 [06:01<00:08,  2.32it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  98%|█████████▊| 882/900 [06:01<00:07,  2.29it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  98%|█████████▊| 883/900 [06:02<00:07,  2.27it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  98%|█████████▊| 884/900 [06:02<00:07,  2.16it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  98%|█████████▊| 885/900 [06:03<00:06,  2.30it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  98%|█████████▊| 886/900 [06:03<00:06,  2.27it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  99%|█████████▊| 887/900 [06:04<00:05,  2.26it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  99%|█████████▊| 888/900 [06:04<00:05,  2.38it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  99%|█████████▉| 889/900 [06:04<00:04,  2.23it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  99%|█████████▉| 890/900 [06:05<00:04,  2.23it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  99%|█████████▉| 891/900 [06:05<00:03,  2.36it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  99%|█████████▉| 892/900 [06:06<00:03,  2.46it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  99%|█████████▉| 893/900 [06:06<00:02,  2.39it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  99%|█████████▉| 894/900 [06:06<00:02,  2.48it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  99%|█████████▉| 895/900 [06:07<00:02,  2.40it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# 100%|█████████▉| 896/900 [06:07<00:01,  2.49it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# 100%|█████████▉| 897/900 [06:08<00:01,  2.55it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# 100%|█████████▉| 898/900 [06:08<00:00,  2.33it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# 100%|█████████▉| 899/900 [06:09<00:00,  2.30it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# 100%|██████████| 900/900 [06:09<00:00,  2.44it/s]
# Accuracy: 0.859
# Accuracy for label 0: 0.943
# Accuracy for label 1: 0.803
# Accuracy for label 2: 0.830
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       300
#            1       0.80      0.80      0.80       300
#            2       0.84      0.83      0.83       300
#
#     accuracy                           0.86       900
#    macro avg       0.86      0.86      0.86       900
# weighted avg       0.86      0.86      0.86       900
#
#
# Confusion Matrix:
# [[283  15   2]
#  [ 12 241  47]
#  [  5  46 249]]

# %% [markdown]
# The following code will create a Pandas DataFrame called evaluation containing the text, true labels, and predicted labels from the test set. This is expectially useful for understanding the errors that the fine-tuned model makes, and gettting insights on how to improve the prompt.

# %%
evaluation = pd.DataFrame({'text': X_test["text"], 
                           'y_true':y_true, 
                           'y_pred': y_pred},
                         )
evaluation.to_csv("test_predictions.csv", index=False)
